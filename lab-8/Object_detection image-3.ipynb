# %% [markdown]
# # Object Detection

# %% [markdown]
# Object detection is a computer vision task that involves identifying and localizing objects within an image or video frame.
#
# It's a fundamental problem in computer vision with various practical applications, including autonomous vehicles, surveillance systems, robotics, medical imaging, and more.

# %%
import sys
# !{sys.executable} -m pip install "transformers<5.0" "huggingface-hub<1.0,>=0.34.0" "gradio<6" "numpy<2" --force-reinstall
# Out:
# Collecting transformers<5.0
#   Using cached transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Collecting huggingface-hub<1.0,>=0.34.0
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting gradio<6
#   Using cached gradio-5.50.0-py3-none-any.whl.metadata (16 kB)
# Collecting numpy<2
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + c:\Users\meet1\anaconda3\python.exe C:\Users\meet1\AppData\Local\Temp\pip-install-m81_s2ge\numpy_36981e1f29ec4e87a56d2de0044c9830\vendored-meson\meson\meson.py setup C:\Users\meet1\AppData\Local\Temp\pip-install-m81_s2ge\numpy_36981e1f29ec4e87a56d2de0044c9830 C:\Users\meet1\AppData\Local\Temp\pip-install-m81_s2ge\numpy_36981e1f29ec4e87a56d2de0044c9830\.mesonpy-4qvw643e -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\meet1\AppData\Local\Temp\pip-install-m81_s2ge\numpy_36981e1f29ec4e87a56d2de0044c9830\.mesonpy-4qvw643e\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\meet1\AppData\Local\Temp\pip-install-m81_s2ge\numpy_36981e1f29ec4e87a56d2de0044c9830
#       Build dir: C:\Users\meet1\AppData\Local\Temp\pip-install-m81_s2ge\numpy_36981e1f29ec4e87a56d2de0044c9830\.mesonpy-4qvw643e
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not parse vswhere.exe output
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\meet1\AppData\Local\Temp\pip-install-m81_s2ge\numpy_36981e1f29ec4e87a56d2de0044c9830\.mesonpy-4qvw643e\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# import libraries
from IPython.display import Image
Image(filename='image-3.jpg')

# %% [markdown]
# # Real life Example
# from IPython.display import Image
# Image(filename='Object_detection.png')

# %%
# To run this code on your own machine, you will need to install the following:

    # to load pre-trained models
#!pip install transformers

    # for creating web interfaces for machine learning models.
#!pip install gradio

    # PyTorch Image Models (timm), a collection of image models (CNN architectures) for PyTorch.
import sys
# !{sys.executable} -m pip install timm

    # for generating plurals, singular nouns, ordinals, and indefinite articles.
import sys
# !{sys.executable} -m pip install inflect

    # for converting text into phonetic (audio) transcriptions.
import sys
# !{sys.executable} -m pip install phonemizer

# install the eSpeak software for TTS (text-to-speech) conversion
# !sudo apt-get install python-espeak
# !sudo apt-get update && sudo apt-get install espeak
# Out:
# Requirement already satisfied: timm in c:\users\meet1\anaconda3\lib\site-packages (1.0.28)
# Requirement already satisfied: torch in c:\users\meet1\anaconda3\lib\site-packages (from timm) (2.13.0)
# Requirement already satisfied: torchvision in c:\users\meet1\anaconda3\lib\site-packages (from timm) (0.28.0)
# Requirement already satisfied: pyyaml in c:\users\meet1\anaconda3\lib\site-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in c:\users\meet1\anaconda3\lib\site-packages (from timm) (0.36.2)
# Requirement already satisfied: safetensors in c:\users\meet1\anaconda3\lib\site-packages (from timm) (0.8.0)
# Requirement already satisfied: filelock in c:\users\meet1\anaconda3\lib\site-packages (from huggingface_hub->timm) (3.31.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\meet1\anaconda3\lib\site-packages (from huggingface_hub->timm) (2026.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\meet1\anaconda3\lib\site-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: requests in c:\users\meet1\anaconda3\lib\site-packages (from huggingface_hub->timm) (2.34.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\meet1\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.69.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\meet1\anaconda3\lib\site-packages (from huggingface_hub->timm) (4.15.0)
# Requirement already satisfied: colorama in c:\users\meet1\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface_hub->timm) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\meet1\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\meet1\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\meet1\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\meet1\anaconda3\lib\site-packages (from requests->huggingface_hub->timm) (2026.6.17)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\meet1\anaconda3\lib\site-packages (from torch->timm) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\meet1\anaconda3\lib\site-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\meet1\anaconda3\lib\site-packages (from torch->timm) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\meet1\anaconda3\lib\site-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\meet1\anaconda3\lib\site-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\meet1\anaconda3\lib\site-packages (from jinja2->torch->timm) (3.0.3)
# Requirement already satisfied: numpy in c:\users\meet1\anaconda3\lib\site-packages (from torchvision->timm) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\meet1\anaconda3\lib\site-packages (from torchvision->timm) (11.3.0)
# Requirement already satisfied: inflect in c:\users\meet1\anaconda3\lib\site-packages (7.5.0)
# Requirement already satisfied: more_itertools>=8.5.0 in c:\users\meet1\anaconda3\lib\site-packages (from inflect) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\meet1\anaconda3\lib\site-packages (from inflect) (4.5.2)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\meet1\anaconda3\lib\site-packages (from typeguard>=4.0.1->inflect) (4.15.0)
# Requirement already satisfied: phonemizer in c:\users\meet1\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: joblib in c:\users\meet1\anaconda3\lib\site-packages (from phonemizer) (1.5.2)
# Requirement already satisfied: segments in c:\users\meet1\anaconda3\lib\site-packages (from phonemizer) (2.4.0)
# Requirement already satisfied: attrs>=18.1 in c:\users\meet1\anaconda3\lib\site-packages (from phonemizer) (25.4.0)
# Requirement already satisfied: dlinfo in c:\users\meet1\anaconda3\lib\site-packages (from phonemizer) (2.0.0)
# Requirement already satisfied: typing-extensions in c:\users\meet1\anaconda3\lib\site-packages (from phonemizer) (4.15.0)
# Requirement already satisfied: regex in c:\users\meet1\anaconda3\lib\site-packages (from segments->phonemizer) (2026.7.19)
# Requirement already satisfied: csvw>=1.5.6 in c:\users\meet1\anaconda3\lib\site-packages (from segments->phonemizer) (4.1.0)
# Requirement already satisfied: isodate in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (0.7.2)
# Requirement already satisfied: python-dateutil in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (2.9.0.post0)
# Requirement already satisfied: rfc3986<2 in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (1.5.0)
# Requirement already satisfied: uritemplate>=3.0.0 in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (4.2.0)
# Requirement already satisfied: babel in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (2.17.0)
# Requirement already satisfied: language-tags in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (1.3.1)
# Requirement already satisfied: rdflib in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (7.6.0)
# Requirement already satisfied: termcolor in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (3.3.0)
# Requirement already satisfied: jsonschema in c:\users\meet1\anaconda3\lib\site-packages (from csvw>=1.5.6->segments->phonemizer) (4.25.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\meet1\anaconda3\lib\site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\meet1\anaconda3\lib\site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\meet1\anaconda3\lib\site-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer) (0.28.0)
# Requirement already satisfied: six>=1.5 in c:\users\meet1\anaconda3\lib\site-packages (from python-dateutil->csvw>=1.5.6->segments->phonemizer) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in c:\users\meet1\anaconda3\lib\site-packages (from rdflib->csvw>=1.5.6->segments->phonemizer) (3.2.5)
# Sudo is disabled on this machine. To enable it, go to the ]8;;ms-settings:developers\Developer Settings page]8;;\ in the Settings app
# Sudo is disabled on this machine. To enable it, go to the ]8;;ms-settings:developers\Developer Settings page]8;;\ in the Settings app

# %% [markdown]
# ### Build the `object-detection` pipeline using the transformers Library
#
# - This model was release with the paper [End-to-End Object Detection with Transformers](https://arxiv.org/abs/2005.12872) from Carion et al. (2020)

# %%
# use the functions from the helper file
from helper import load_image_from_url, render_results_in_image

# %%
# import pipeline from transformers
from transformers import pipeline

# %%
# code to suppress warning messages
from transformers.utils import logging
logging.set_verbosity_error()

from helper import ignore_warnings
ignore_warnings()

# %%
# Import the model and create an instance
od_pipe = pipeline("object-detection", "facebook/detr-resnet-50")
# Out:
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.0.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.0.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.0.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.0.downsample.0.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.downsample.1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.0.downsample.1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.1.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.1.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.1.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.1.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.1.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.1.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.1.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.1.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.1.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.2.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.2.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.2.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.2.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.2.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.2.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer1.2.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.2.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer1.2.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.0.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.0.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.0.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.0.downsample.0.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.downsample.1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.0.downsample.1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.1.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.1.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.1.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.1.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.1.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.1.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.1.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.1.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.1.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.2.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.2.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.2.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.2.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.2.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.2.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.2.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.2.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.2.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.3.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.3.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.3.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.3.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.3.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.3.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer2.3.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.3.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer2.3.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.0.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.0.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.0.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.0.downsample.0.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.downsample.1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.0.downsample.1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.1.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.1.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.1.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.1.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.1.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.1.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.1.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.1.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.1.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.2.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.2.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.2.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.2.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.2.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.2.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.2.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.2.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.2.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.3.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.3.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.3.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.3.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.3.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.3.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.3.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.3.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.3.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.4.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.4.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.4.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.4.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.4.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# ...
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.5.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.5.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.5.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.5.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.5.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer3.5.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.5.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer3.5.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.0.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.0.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.0.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.0.downsample.0.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.downsample.1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.0.downsample.1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.1.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.1.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.1.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.1.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.1.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.1.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.1.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.1.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.1.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.2.conv1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.2.bn1.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.2.bn1.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.2.conv2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.2.bn2.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.2.bn2.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2588: UserWarning: for layer4.2.conv3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   module._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.2.bn3.weight: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(
# c:\Users\meet1\anaconda3\Lib\site-packages\torch\nn\modules\batchnorm.py:141: UserWarning: for layer4.2.bn3.bias: copying from a non-meta parameter in the checkpoint to a meta parameter in the current model, which is a no-op. (Did you mean to pass `assign=True` to assign items in the state dictionary to their corresponding key in the module instead of copying them in place?)
#   super()._load_from_state_dict(

# %% [markdown]
# Info about [facebook/detr-resnet-50](https://huggingface.co/facebook/detr-resnet-50)

# %% [markdown]
# Explore more of the [Hugging Face Hub for more object detection models](https://huggingface.co/models?pipeline_tag=object-detection&sort=trending)

# %% [markdown]
# ### Use the Pipeline

# %%
# Python Image Library
from PIL import Image

# %%
# Import the image
raw_image = Image.open('image-3.jpg')

# Resize as pre-processing step for standardized input size
raw_image.resize((500, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=500x400>

# %%
# runt the model
pipeline_output = od_pipe(raw_image)

# %%
# valide the results
pipeline_output
# Out:
# [{'score': 0.999372661113739,
#   'label': 'dog',
#   'box': {'xmin': 651, 'ymin': 344, 'xmax': 794, 'ymax': 541}},
#  {'score': 0.999602735042572,
#   'label': 'person',
#   'box': {'xmin': 294, 'ymin': 85, 'xmax': 441, 'ymax': 522}},
#  {'score': 0.9996488094329834,
#   'label': 'person',
#   'box': {'xmin': 445, 'ymin': 115, 'xmax': 599, 'ymax': 526}},
#  {'score': 0.9856728315353394,
#   'label': 'handbag',
#   'box': {'xmin': 504, 'ymin': 185, 'xmax': 586, 'ymax': 342}}]

# %% [markdown]
# - Return the results from the pipeline using the helper function `render_results_in_image`.

# %%
# render the image
processed_image = render_results_in_image(
    raw_image,
    pipeline_output)

# %%
# view the final output
processed_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1155x770>

# %% [markdown]
# ### Using `Gradio` to create a Simple Interface
#
# Gradio is a Python library that simplifies the process of creating web interfaces for machine learning models. It allows you to quickly build interactive web-based applications where users can interact with your machine learning models without needing to write any HTML, CSS, or JavaScript code.
#
# Once you've imported Gradio, you can use its functions and classes to define input and output components, specify your machine learning model, and create a web interface that integrates with your model.

# %%
# import gradio
import gradio as gr

# %%
# this function will do all the steps under the hood

def get_pipeline_prediction(pil_image):

    # this will process the image and identify the objects
    pipeline_output = od_pipe(pil_image)

    # This will output the labelled image with boxes and confidence score
    processed_image = render_results_in_image(pil_image, pipeline_output)

    return processed_image

# %%
demo = gr.Interface(
  fn=get_pipeline_prediction,
  inputs=gr.Image(label="Input image",
                  type="pil"),
  outputs=gr.Image(label="Output image with predicted instances",
                   type="pil")
)

# %% [markdown]
# - `share=True` will provide an online link to access to the demo

# %%
# share=True will create a public link for sharing
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Close the app
# - Remember to call `.close()` on the Gradio app when you're done using it.

# %%
# close when done
demo.close()
# Out:
# Closing server running on port: 7860

# %% [markdown]
# ## Audio Assistant

# %% [markdown]
# - Combine the object detector with a text-to-speech model that will help dictate what is inside the image.

# %%
# Remember, our pipeline_output has the raw output from the object detection model
pipeline_output
# Out:
# [{'score': 0.999372661113739,
#   'label': 'dog',
#   'box': {'xmin': 651, 'ymin': 344, 'xmax': 794, 'ymax': 541}},
#  {'score': 0.999602735042572,
#   'label': 'person',
#   'box': {'xmin': 294, 'ymin': 85, 'xmax': 441, 'ymax': 522}},
#  {'score': 0.9996488094329834,
#   'label': 'person',
#   'box': {'xmin': 445, 'ymin': 115, 'xmax': 599, 'ymax': 526}},
#  {'score': 0.9856728315353394,
#   'label': 'handbag',
#   'box': {'xmin': 504, 'ymin': 185, 'xmax': 586, 'ymax': 342}}]

# %%
raw_image = Image.open('image-3.jpg')
raw_image.resize((284, 245))
# Out:
# <PIL.Image.Image image mode=RGB size=284x245>

# %%
# This will convert the raw output to a readable output
from helper import summarize_predictions_natural_language

text = summarize_predictions_natural_language(pipeline_output)
text
# Out:
# 'In this image, there are one dog two persons and one handbag.'

# %% [markdown]
# ## Generate Audio Narration of this Image

# %%
# Pipeline design
from IPython.display import Image
Image(filename='image-3.jpg')

# %%
# Text to Speech model
tts_pipe = pipeline("text-to-speech", model="kakao-enterprise/vits-ljs")

# %%
#from transformers import pipeline
tts_pipe = pipeline("text-to-audio", model="suno/bark-small")
tts_pipe

# %% [markdown]
# More info about [kakao-enterprise/vits-ljs](https://huggingface.co/kakao-enterprise/vits-ljs).

# %%
narrated_text = tts_pipe(text)

# %% [markdown]
# ### Play the Generated Audio

# %%
from IPython.display import Audio as IPythonAudio

# %%
IPythonAudio(narrated_text["audio"][0],
             rate=narrated_text["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Try it yourself!
# - Try these models with other images!
